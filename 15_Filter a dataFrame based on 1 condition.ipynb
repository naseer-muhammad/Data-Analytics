# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with Pandas
# Target Webiste: https://www.football-data.co.uk/data.php

# %%
# Reading 1 csv from the website
df_premiet25 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2526/E0.csv")

# %%
# showing dataframe
df_premiet25

# %%
# Rename Columns
df_premiet25.rename(columns={"FTHG":"home_goals",	"FTAG":"away_goals"}, inplace=True)

# %%
# Show dataframe
df_premiet25

# %% [markdown]
# # Read a .csv from multiple URLs with Pandas
# - Target Webiste: https://www.football-data.co.uk/data.
# - https://www.football-data.co.uk/mmz4281/2526/E1.csv
# - https://www.football-data.co.uk/mmz4281/2526/E2.csv
# - https://www.football-data.co.uk/mmz4281/2526/E3.csv
# - https://www.football-data.co.uk/mmz4281/2526/EC.csv

# %%
# link structure
"https://www.football-data.co.uk/mmz4281/" + "2526" + "/" + "E1" + ".csv"

# %%
# Create a root variable
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# # Multiple leagues
# - https://www.football-data.co.uk/mmz4281/2526/E0.csv
# - https://www.football-data.co.uk/mmz4281/2526/E1.csv
# - https://www.football-data.co.uk/mmz4281/2526/E2.csv
# - https://www.football-data.co.uk/mmz4281/2526/E3.csv
# - https://www.football-data.co.uk/mmz4281/2526/EC.csv

# %%
# creating list of leagues
leagues = ["E0", "E1", "E2", "E3", "EC"]
frames = []
# Looping through leagues, read multiple csv and append it into a list
for league in leagues:
    df = pd.read_csv(root + "2526" + "/" + league + ".csv")
    frames.append(df)

# %%
# length of frames
len(frames)

# %%
# show 1st, 2nd, 3rd, elements
frames[2]

# %% [markdown]
# ## Multiple Seasons

# %%
for season in range(15, 16):
    print(str(season)+str(season+1))

# %%
# Creating list of leagues
leagues = ["E0", "E2"]
frames = []
# Loop through range of seasons and insert new column
for league in leagues:
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + league)
        df.insert(1, "season", season)
        frames.append(df)

# %%
# total frames (6 seasons x 3 leagues)
len(frames)
