# %%
import pandas as pd

# %% [markdown]
# ## Example of Data

# %%
# data used for example
states = ["Florida", "Michigan", "New York", "Pakistan"]
population = [222, 333, 4444, 5555]  
dict_states = {"Provinces of USA": states, "Abaadi": population} 
# The number of element in 'states' and 'population must be same

df_population = pd.DataFrame.from_dict(dict_states)
df_population
# Out:
#   Provinces of USA  Abaadi
# 0          Florida     222
# 1         Michigan     333
# 2         New York    4444
# 3         Pakistan    5555

# %%
df_population.head(2)
# Out:
#   Provinces of USA  Abaadi
# 0          Florida     222
# 1         Michigan     333

# %%
df_population.tail(1)
# Out:
#   Provinces of USA  Abaadi
# 3         Pakistan    5555
