# %%
import pandas as pd

# %%
# Reading the CSV File
df_exam = pd.read_csv("StudentsPerformance.csv")
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1. Adding a new Column

# %% [markdown]
# ### 1.1 Adding a new Column with a scalar value

# %%
# Adding a new column to dataframe
df_exam["Language Score"]=70

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ### 1.2 Adding a new column with an array

# %%
# Import numpy
import numpy as np

# %%
# Create an array of 1000 elements
language_score = np.arange(0, 1000)

# %%
len(language_score)
# Out:
# 1000

# %%
# Adding new column to dataframe with an array
df_exam["language_score"]= language_score
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Create random integer numbers between 1 and 100
int_language_score = np.random.randint(33, 100, size = 1000)

# %%
# Minimum and Maximum value inclusive and high value exclusive
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 33
# 99

# %%
# Adding new column to dataframe with an array
df_exam["language_score"]= int_language_score
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Creating random float numbers
np.random.uniform(33, 100, size = 300)
# Out:
# array([78.11412243, 91.94952374, 83.32298118, 45.83402949, 89.52646818,
#        33.59358929, 33.04585776, 65.36037215, 86.52513495, 90.80797127,
#        81.60924861, 55.27504838, 37.70179889, 76.42973921, 84.64788152,
#        42.58590088, 96.95792613, 90.77120432, 67.33258385, 85.00438351,
#        81.3318007 , 55.22156348, 77.58527192, 68.16625937, 84.91225194,
#        99.89618501, 98.0627436 , 71.57203376, 77.46918119, 78.03042836,
#        89.84971616, 46.44372886, 44.14435254, 50.04804798, 47.2195602 ,
#        75.21844378, 68.16833239, 90.88913431, 33.95568578, 84.61314482,
#        96.92490394, 85.16395529, 74.5032617 , 49.04674343, 74.57905106,
#        35.33971033, 68.93313384, 56.46182009, 59.26021695, 37.39161143,
#        49.01440665, 53.28955832, 42.31975939, 71.13594434, 41.25480388,
#        66.05111691, 82.7832167 , 87.2143968 , 82.90534919, 53.12380796,
#        61.65617782, 94.97730675, 63.08283094, 45.96799687, 38.85561825,
# ...
